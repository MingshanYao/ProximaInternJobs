# %%
import pandas as pd

# %%
path = '/data/niezl/TCT/TCT_Data/Detection/0513/影像标注结果.csv'
csv = pd.read_csv(path)

# %%
csv.head()
# Out:
#    用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 0  5274  173686  fc71b18c13a44fb3b9b7226dfad8416f  NaN  ANNO9  RECTANGLE
# 1  5274  173687  fc71b18c13a44fb3b9b7226dfad8416f  NaN  ANNO9  RECTANGLE
# 2  5274  173685  fc71b18c13a44fb3b9b7226dfad8416f  NaN  ANNO9  RECTANGLE
# 3  5274  173690  fc71b18c13a44fb3b9b7226dfad8416f  NaN  ANNO9  RECTANGLE
# 4  5274  173691  fc71b18c13a44fb3b9b7226dfad8416f  NaN  ANNO9  RECTANGLE
#
#    影像结果类型                                               影像结果  自定义内容  恶性细胞分类
# 0       2  {"point1":{"x":7.065693430656934,"y":136.95377...    NaN       1
# 1       2  {"point1":{"x":1764.068126520681,"y":443.13381...    NaN       1
# 2       2  {"point1":{"x":741.8978102189781,"y":991.90267...    NaN       1
# 3       2  {"point1":{"x":296.7591240875912,"y":937.73236...    NaN       1
# 4       2  {"point1":{"x":1135.221411192214,"y":12.126520...    NaN       1

# %%
csv.loc[csv['序列编号']=='594b835c56a54b749e5f66e7e6d7f97d']
# Out:
#      用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 268  5274  146262  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 269  5274  146266  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 270  5274  146264  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 271  5274  146265  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 272  5274  146268  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 273  5274  146278  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 274  5274  146276  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 275  5274  146288  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 276  5274  146302  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
# 277  5274  146303  594b835c56a54b749e5f66e7e6d7f97d  NaN  ANNO9  RECTANGLE
#
#      影像结果类型                                               影像结果  自定义内容  恶性细胞分类
# ...

# %%
csv.loc[csv['序列编号']=='c9006d2c3ab54de4bd53069ebd084604']
# Out:
#       用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 4158  5213  155799  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4159  5213  155801  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4160  5213  155807  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4161  5213  155804  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4162  5213  155810  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4163  5213  155817  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4164  5213  155823  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4165  5213  155821  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4166  5213  155844  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4167  5213  155851  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# 4168  5213  155865  c9006d2c3ab54de4bd53069ebd084604  NaN  ANNO9  RECTANGLE
# ...

# %%
csv.loc[csv['序列编号']=='8f45c5479cec4a17addcba927669cd03']
# Out:
#       用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 4439  5211  156486  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4440  5211  156490  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4441  5211  156488  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4442  5211  156494  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4443  5211  156495  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4444  5211  156501  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
# 4445  5211  156539  8f45c5479cec4a17addcba927669cd03  NaN  ANNO9  RECTANGLE
#
#       影像结果类型                                               影像结果  自定义内容  恶性细胞分类
# 4439       2  {"point1":{"x":309.00221739953713,"y":1087.401...    NaN       2
# 4440       2  {"point1":{"x":303.6415094339622,"y":12.132075...    NaN       1
# 4441       2  {"point1":{"x":929.1886792452829,"y":434.49056...    NaN       1
# ...

# %%
csv.loc[csv['序列编号']=='ae71e02c05f245e5a8a09b14bfaed051']
# Out:
#       用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 3531  5211  160634  ae71e02c05f245e5a8a09b14bfaed051  NaN  ANNO9  RECTANGLE
#
#       影像结果类型                                               影像结果  自定义内容  恶性细胞分类
# 3531       2  {"point1":{"x":1235.1132075471696,"y":151.3962...    NaN       1

# %%
csv.loc[csv['序列编号']=='ec0d82b238214f1f90480d91924913b5']
# Out:
#       用户编号  影像结果编号                              序列编号  阴阳性     病灶       影像工具  \
# 1883  5211  173266  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1884  5211  173267  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1885  5211  173265  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1886  5211  173269  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1887  5211  173272  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1888  5211  173277  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1889  5211  173280  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1890  5211  173286  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1891  5211  173287  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1892  5211  173284  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# 1893  5211  173294  ec0d82b238214f1f90480d91924913b5  NaN  ANNO9  RECTANGLE
# ...

# %%
best_paiyin=0.989
fnr = 0.1
epoch=100
'epoch_%d_best_paiyin_%.3f_recall_%.3f.pth'%(epoch,best_paiyin, 1-fnr)
# Out:
# 'epoch_100_best_paiyin_0.989_recall_0.900.pth'
