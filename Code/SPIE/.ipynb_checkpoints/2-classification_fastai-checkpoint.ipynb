# %%
from fastai import *
from fastai.vision import *
from fastai.callbacks import CSVLogger
import os
import pandas as pd
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-bed082703884> in <module>()
# ----> 1 from fastai import *
#       2 from fastai.vision import *
#       3 from fastai.callbacks import CSVLogger
#       4 import os
#       5 import pandas as pd
#
# ImportError: No module named fastai

# %%
# !sudo conda install -c fastai fastai
# Out:
# [sudo] password for yaoms:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.cuda.set_device(1)

# %%
train_label = pd.read_csv("/data/Pathology/SPIE/training_set/breastpathq/datasets/train_labels.csv")
val_label = pd.read_csv("/data/Pathology/SPIE/training_set/breastpathq/datasets/val_labels.csv")

# %%
train_label['slide_name'] = "train/"+ train_label['slide'].astype(str) + "_" + train_label['rid'].astype(str) + ".tif"
val_label['slide_name'] = "validation/"+ val_label['slide'].astype(str) + "_" + val_label['rid'].astype(str) + ".tif"
train_label['is_valid'] = False
val_label['is_valid'] = True

# %%
full_label = train_label.append(val_label)
full_label.shape
# Out:
# (2579, 5)

# %%
full_label['label'] = 1

# %%
full_label.label[full_label.y == 0] = 0
# Out:
# /root/anaconda2/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
full_label.head()
# Out:
#    slide  rid     y         slide_name  is_valid  label
# 0  99861    1  0.40  train/99861_1.tif     False      1
# 1  99861    2  0.40  train/99861_2.tif     False      1
# 2  99861    3  0.15  train/99861_3.tif     False      1
# 3  99861    4  0.10  train/99861_4.tif     False      1
# 4  99861    5  0.07  train/99861_5.tif     False      1

# %%
tfms = get_transforms(max_zoom=1., max_lighting=0.20, max_warp=None, do_flip=True, 
                      flip_vert=True, max_rotate=None,)
bs = 16  # batch size
sz= 512 # image size
root_dir = "/data/Pathology/SPIE/training_set/breastpathq/datasets/"
data = (ImageList.from_df(full_label, root_dir, cols=['slide_name'])
        #Where to find the data? -> in planet 'train' folder
        .split_from_df(col='is_valid')
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_df(cols='label')
        #How to label? -> use the second column of the csv file and split the tags by ' '        
        .transform(tfms,size=512)
        #Data augmentation? -> use tfms with a size of 128
        .databunch(bs=bs, num_workers=16)
        .normalize(imagenet_stats))                          
        #Finally -> use the defaults for conversion to databunch

# %%
data.train_ds
# Out:
# LabelList (2394 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# 1,1,1,1,1
# Path: /data/Pathology/SPIE/training_set/breastpathq/datasets

# %%
model_path = Path("/data/yuyue/SPIE/model_weight/")
learn = cnn_learner(data, models.resnet50, metrics=accuracy, model_dir=model_path, 
                    loss_func=CrossEntropyFlat(),  callback_fns=[ShowGraph,])
# make output [0...1], don't foreget to add sigmoid at the end of model
# learn.model[1].add_module("sigmoid", module=nn.Sigmoid())

# %%
learn.load('/data/yuyue/SPIE/model_weight/2-class')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2394 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 1,1,1,1,1
# Path: /data/Pathology/SPIE/training_set/breastpathq/datasets;
#
# Valid: LabelList (185 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 1,1,1,1,1
# Path: /data/Pathology/SPIE/training_set/breastpathq/datasets;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
learn.data = data

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, max_lr=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.126706</td>
#       <td>0.186889</td>
#       <td>0.908108</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.133376</td>
#       <td>1.119601</td>
#       <td>0.691892</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.176955</td>
#       <td>0.698798</td>
#       <td>0.681081</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.123964</td>
#       <td>0.450288</td>
#       <td>0.789189</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.110998</td>
#       <td>0.204945</td>
#       <td>0.918919</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-5))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 01:02<01:34]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.029898</td>
# ...

# %%
learn.save('/data/yuyue/SPIE/model_weight/2-class')

# %%
learn.load('/data/yuyue/SPIE/model_weight/2-class')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2394 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 1,1,1,1,1
# Path: /data/Pathology/SPIE/training_set/breastpathq/datasets;
#
# Valid: LabelList (185 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 1,1,1,1,1
# Path: /data/Pathology/SPIE/training_set/breastpathq/datasets;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
# ...
