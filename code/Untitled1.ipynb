# %%
path = '/home/niezl/Yolo_v3/output'
from PIL import Image
img = Image.open(path+'/'+'000001.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=575x320 at 0x7FDE7B8B1668>
