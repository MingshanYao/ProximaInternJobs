# %%
import sys
import torch
import torchvision
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from PIL import Image
import torchvision.transforms as transforms
import os
import cv2
from torch.utils.data import DataLoader, TensorDataset, Dataset

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append("/home/shiyi/gpu/")

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,2,5"  # specify which GPU(s) to be used
from gpu_allocation import set_gpu
num_gpu = 1
set_gpu(num_gpu)
# Out:
# Found 8 GPU(s) only 4 gpu below threshold
# Using GPU 2

# %%
#hyperparameters 

IMG_SIZE = 224
BATCH_SIZE = 16
CLASSES = 8
EPOCH = 200

IMG_MEAN = [0.485, 0.456, 0.406]
IMG_STD = [0.229, 0.224, 0.225]

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

LR = 0.001

# %%
#dir and path

csv_path = '/data/AlgProj/tct_yaoms/data/tct_0513/include_background_0723.csv'
csv = pd.read_csv(csv_path)

# %%
#train test dataset split
#train val transforms definition

# def train_test_split(df, test_size, shuffle=True):
#     if shuffle:
#         df = df.sample(frac=1).reset_index(drop=True)
#     #split
#     length = len(df)
#     threspoint = int((1 - test_size)*length)
#     train_df = df.loc[:threspoint-1,:]
#     test_df = df.loc[threspoint:,:]
    
#     d = {}
#     d['train'] = train_df
#     d['test'] = test_df.reset_index(drop=True)
#     return d

train_transformer = transforms.Compose([transforms.Resize((256,256)),
                                 transforms.RandomRotation((-180, 180)),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.RandomResizedCrop((224,224)),  
                                 transforms.ToTensor(),
                                       transforms.Normalize(IMG_MEAN,IMG_STD)]
                                )
test_transformer = transforms.Compose([transforms.Resize((256,256)),
                                  transforms.CenterCrop((224,224)),
                                 transforms.ToTensor(),
                                      transforms.Normalize(IMG_MEAN,IMG_STD)])
train_test_transformer = {'train':train_transformer, 'test':test_transformer}

# %%
# train_test_dict = train_test_split(csv, 0.2)
# len(train_test_dict['test'])

train_csv_path = '/data/AlgProj/tct_yaoms/data/tct_0513/train_df.csv'
test_csv_path = '/data/AlgProj/tct_yaoms/data/tct_0513/test_df.csv'
train_csv = pd.read_csv(train_csv_path)
test_csv = pd.read_csv(test_csv_path)
train_test_dict = {'train':train_csv, 'test': test_csv}
len(train_test_dict['test'])
# Out:
# 1018

# %%
class TCT_Dataset(Dataset):
    def __init__(self, phase, transforms=True):
        self.phase = phase
        self.transforms = transforms
        if phase == 'train':
            self.df = train_test_dict['train']
        else:
            self.df = train_test_dict['test']
        
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,idx):
        img_path = self.df.loc[idx, 'img_path']
        img = Image.open(img_path).convert('RGB')
        label = self.df.loc[idx, 'label']
        
        if self.transforms:
            if self.phase == 'train':
                transformer = train_test_transformer['train']
            else:
                transformer = train_test_transformer['test']

            img = transformer(img)
        
        return (img, label)

# %%
train_dataset = TCT_Dataset('train')
test_dataset = TCT_Dataset('test')

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
from torchvision.models import resnet50
model = resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = False

fc_features = model.fc.in_features
model.fc = torch.nn.Linear(fc_features, CLASSES)

model.to(DEVICE)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=8, bias=True)
# )

# %%
optimizer = optim.SGD([{'params':model.fc.parameters(), 'lr':0.001}])
#                        {'params':model.layer4.parameters(),'lr':0.00001}
criterion = nn.CrossEntropyLoss()

# %%
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

    print ('Train Epoch: {}\t Loss: {:.6f}\n'.format(epoch,loss.item()))

    
def test(model, device, test_loader, optimizer):
    model.eval()
    test_loss = 0
    correct = 0
#     pred_result = []
    with torch.no_grad():
        for i,data in enumerate(test_loader):          
            x,y= data
            x=x.to(device)
            y=y.to(device)
            optimizer.zero_grad()
            y_hat = model(x)
            test_loss = criterion(y_hat, y).item() # sum up batch loss
            pred = y_hat.max(1, keepdim=True)[1] # get the index of the max log-probability
            
            correct += pred.eq(y.view_as(pred)).sum().item()
#     test_loss /= len(test_loader.dataset)
    acc = 100. * correct / len(train_test_dict['test'])
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(train_test_dict['test']),
        acc))
    
#     print('-----------------------')
    return acc

# %%
max_acc = 0
max_epoch = 0
max_acc = 0.6
save_path = '/data/AlgProj/tct_yaoms/model/resnet-50_include_ascus_0722.pth'
for epoch in range(EPOCH):
    train(model, DEVICE, train_loader, optimizer, epoch)
    acc = test(model, DEVICE, test_loader, optimizer)
    if acc >= max_acc:
        max_acc = acc
        max_epoch = epoch
        if os.path.exists(save_path):
            os.remove(save_path)
        torch.save(model, save_path)
    print('current best acc: ', max_acc)
    print('-----------------------')
print('Result: at {} epoch, achieved best acc: {:.0f}'.format(max_epoch, max_acc))
# Out:
# Train Epoch: 0	 Loss: 1.290413
#
#
# Test set: Average loss: 1.0929, Accuracy: 625/1018 (61%)
#
# current best acc:  61.39489194499018
# -----------------------
# Train Epoch: 1	 Loss: 2.018848
#
#
# Test set: Average loss: 1.0235, Accuracy: 637/1018 (63%)
#
# current best acc:  62.57367387033399
# -----------------------
# Train Epoch: 2	 Loss: 1.301760
#
#
# Test set: Average loss: 1.0156, Accuracy: 650/1018 (64%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 3	 Loss: 2.165635
#
#
# Test set: Average loss: 1.0565, Accuracy: 641/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 4	 Loss: 1.875406
#
#
# Test set: Average loss: 1.0186, Accuracy: 640/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 5	 Loss: 2.154572
#
#
# Test set: Average loss: 1.1572, Accuracy: 626/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 6	 Loss: 0.818654
#
#
# Test set: Average loss: 1.0263, Accuracy: 643/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 7	 Loss: 1.317188
#
#
# Test set: Average loss: 1.0572, Accuracy: 631/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 8	 Loss: 1.448359
#
#
# Test set: Average loss: 1.0898, Accuracy: 626/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 9	 Loss: 1.462014
#
#
# Test set: Average loss: 1.0622, Accuracy: 640/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 10	 Loss: 1.455035
#
#
# Test set: Average loss: 1.0598, Accuracy: 629/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 11	 Loss: 1.547066
#
#
# Test set: Average loss: 0.9929, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 12	 Loss: 1.177125
#
#
# Test set: Average loss: 1.0760, Accuracy: 640/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 13	 Loss: 1.004935
#
#
# Test set: Average loss: 1.0673, Accuracy: 625/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 14	 Loss: 1.067553
#
#
# Test set: Average loss: 1.0529, Accuracy: 639/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 15	 Loss: 1.956063
#
#
# Test set: Average loss: 1.0389, Accuracy: 621/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 16	 Loss: 1.081070
#
#
# Test set: Average loss: 1.1083, Accuracy: 634/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 17	 Loss: 1.673296
#
#
# Test set: Average loss: 1.0763, Accuracy: 636/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 18	 Loss: 0.644452
#
#
# Test set: Average loss: 1.0259, Accuracy: 637/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 19	 Loss: 0.999575
#
#
# Test set: Average loss: 1.0828, Accuracy: 644/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 20	 Loss: 0.633571
#
#
# Test set: Average loss: 1.1212, Accuracy: 635/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 21	 Loss: 1.003837
#
#
# Test set: Average loss: 1.1343, Accuracy: 639/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 22	 Loss: 1.516491
#
#
# Test set: Average loss: 1.0588, Accuracy: 641/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 23	 Loss: 0.874286
#
#
# Test set: Average loss: 1.0078, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 24	 Loss: 1.021564
#
#
# Test set: Average loss: 1.1314, Accuracy: 636/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 25	 Loss: 1.262311
#
#
# Test set: Average loss: 1.0470, Accuracy: 641/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 26	 Loss: 0.973653
#
#
# Test set: Average loss: 1.0868, Accuracy: 632/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 27	 Loss: 1.310137
#
#
# Test set: Average loss: 1.0287, Accuracy: 636/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 28	 Loss: 1.126315
#
#
# Test set: Average loss: 1.1140, Accuracy: 636/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 29	 Loss: 1.736594
#
#
# Test set: Average loss: 1.0595, Accuracy: 633/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 30	 Loss: 1.444088
#
#
# Test set: Average loss: 1.0651, Accuracy: 633/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 31	 Loss: 1.308497
#
#
# Test set: Average loss: 1.0983, Accuracy: 621/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 32	 Loss: 1.315114
#
#
# Test set: Average loss: 1.0866, Accuracy: 639/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 33	 Loss: 0.851645
#
#
# Test set: Average loss: 0.9819, Accuracy: 650/1018 (64%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 34	 Loss: 1.109892
#
#
# Test set: Average loss: 1.0867, Accuracy: 634/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 35	 Loss: 1.593463
#
#
# Test set: Average loss: 1.1034, Accuracy: 635/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 36	 Loss: 1.070522
#
#
# Test set: Average loss: 1.1162, Accuracy: 628/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 37	 Loss: 1.493686
#
#
# Test set: Average loss: 1.0181, Accuracy: 636/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 38	 Loss: 1.132746
#
#
# Test set: Average loss: 1.1221, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 39	 Loss: 1.197769
#
#
# Test set: Average loss: 1.0649, Accuracy: 644/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 40	 Loss: 1.321520
#
#
# Test set: Average loss: 1.0454, Accuracy: 644/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 41	 Loss: 0.829491
#
#
# Test set: Average loss: 1.0439, Accuracy: 640/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 42	 Loss: 1.152692
#
#
# Test set: Average loss: 1.0636, Accuracy: 626/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 43	 Loss: 0.910941
#
#
# Test set: Average loss: 1.0916, Accuracy: 626/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 44	 Loss: 1.877493
#
#
# Test set: Average loss: 1.0612, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 45	 Loss: 1.289588
#
#
# Test set: Average loss: 1.0582, Accuracy: 642/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 46	 Loss: 0.919010
#
#
# Test set: Average loss: 1.0857, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 47	 Loss: 2.095497
#
#
# Test set: Average loss: 0.9667, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 48	 Loss: 1.458455
#
#
# Test set: Average loss: 1.0554, Accuracy: 649/1018 (64%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 49	 Loss: 0.572161
#
#
# Test set: Average loss: 1.0420, Accuracy: 638/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 50	 Loss: 1.244129
#
#
# Test set: Average loss: 1.1166, Accuracy: 633/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 51	 Loss: 1.556756
#
#
# Test set: Average loss: 1.0752, Accuracy: 626/1018 (61%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 52	 Loss: 0.940328
#
#
# Test set: Average loss: 1.0803, Accuracy: 631/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 53	 Loss: 1.052199
#
#
# Test set: Average loss: 1.0382, Accuracy: 628/1018 (62%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 54	 Loss: 1.602245
#
#
# Test set: Average loss: 1.0586, Accuracy: 640/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 55	 Loss: 0.844981
#
#
# Test set: Average loss: 1.1163, Accuracy: 642/1018 (63%)
#
# current best acc:  63.850687622789785
# -----------------------
# Train Epoch: 56	 Loss: 1.478448
#
#
# Test set: Average loss: 1.0139, Accuracy: 651/1018 (64%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 57	 Loss: 0.873732
#
#
# Test set: Average loss: 1.1006, Accuracy: 636/1018 (62%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 58	 Loss: 1.344211
#
#
# Test set: Average loss: 1.0626, Accuracy: 630/1018 (62%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 59	 Loss: 1.077658
#
#
# Test set: Average loss: 1.0572, Accuracy: 640/1018 (63%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 60	 Loss: 2.274013
#
#
# Test set: Average loss: 1.0401, Accuracy: 643/1018 (63%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 61	 Loss: 0.738845
#
#
# Test set: Average loss: 1.0789, Accuracy: 640/1018 (63%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 62	 Loss: 1.498109
#
#
# Test set: Average loss: 1.0938, Accuracy: 630/1018 (62%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 63	 Loss: 0.792698
#
#
# Test set: Average loss: 1.1104, Accuracy: 649/1018 (64%)
#
# current best acc:  63.948919449901766
# -----------------------
# Train Epoch: 64	 Loss: 1.300313
#
#
# Test set: Average loss: 1.0344, Accuracy: 656/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 65	 Loss: 1.983085
#
#
# Test set: Average loss: 1.0162, Accuracy: 639/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 66	 Loss: 0.665863
#
#
# Test set: Average loss: 1.1223, Accuracy: 635/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 67	 Loss: 1.102819
#
#
# Test set: Average loss: 1.1033, Accuracy: 648/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 68	 Loss: 1.277325
#
#
# Test set: Average loss: 1.0431, Accuracy: 641/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 69	 Loss: 2.012568
#
#
# Test set: Average loss: 1.0451, Accuracy: 639/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 70	 Loss: 2.218417
#
#
# Test set: Average loss: 1.0381, Accuracy: 649/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 71	 Loss: 1.452037
#
#
# Test set: Average loss: 1.0272, Accuracy: 650/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 72	 Loss: 0.963850
#
#
# Test set: Average loss: 1.0395, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 73	 Loss: 1.050342
#
#
# Test set: Average loss: 1.0702, Accuracy: 636/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 74	 Loss: 0.631165
#
#
# Test set: Average loss: 1.0201, Accuracy: 643/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 75	 Loss: 1.633206
#
#
# Test set: Average loss: 1.0257, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 76	 Loss: 0.769559
#
#
# Test set: Average loss: 1.1438, Accuracy: 637/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 77	 Loss: 0.881001
#
#
# Test set: Average loss: 1.0653, Accuracy: 645/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 78	 Loss: 1.332701
#
#
# Test set: Average loss: 1.1262, Accuracy: 637/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 79	 Loss: 1.821244
#
#
# Test set: Average loss: 1.0693, Accuracy: 649/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 80	 Loss: 0.765487
#
#
# Test set: Average loss: 1.1119, Accuracy: 636/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 81	 Loss: 1.183475
#
#
# Test set: Average loss: 1.0064, Accuracy: 627/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 82	 Loss: 0.664730
#
#
# Test set: Average loss: 1.0446, Accuracy: 633/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 83	 Loss: 1.186867
#
#
# Test set: Average loss: 1.0278, Accuracy: 631/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 84	 Loss: 1.218931
#
#
# Test set: Average loss: 1.0719, Accuracy: 635/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 85	 Loss: 0.576463
#
#
# Test set: Average loss: 1.1135, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 86	 Loss: 1.089466
#
#
# Test set: Average loss: 1.0460, Accuracy: 640/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 87	 Loss: 1.335841
#
#
# Test set: Average loss: 1.0541, Accuracy: 637/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 88	 Loss: 1.290932
#
#
# Test set: Average loss: 1.1086, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 89	 Loss: 1.060745
#
#
# Test set: Average loss: 1.0216, Accuracy: 642/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 90	 Loss: 1.801111
#
#
# Test set: Average loss: 1.1093, Accuracy: 632/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 91	 Loss: 0.886972
#
#
# Test set: Average loss: 1.0118, Accuracy: 647/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 92	 Loss: 0.898005
#
#
# Test set: Average loss: 1.0372, Accuracy: 632/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 93	 Loss: 1.187695
#
#
# Test set: Average loss: 1.0317, Accuracy: 642/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 94	 Loss: 1.025866
#
#
# Test set: Average loss: 1.0376, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 95	 Loss: 1.724369
#
#
# Test set: Average loss: 1.0142, Accuracy: 649/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 96	 Loss: 1.167357
#
#
# Test set: Average loss: 1.0860, Accuracy: 627/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 97	 Loss: 0.388307
#
#
# Test set: Average loss: 1.0677, Accuracy: 637/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 98	 Loss: 1.366467
#
#
# Test set: Average loss: 1.0240, Accuracy: 647/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 99	 Loss: 2.465857
#
#
# Test set: Average loss: 1.0359, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 100	 Loss: 0.743668
#
#
# Test set: Average loss: 1.1088, Accuracy: 625/1018 (61%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 101	 Loss: 0.636224
#
#
# Test set: Average loss: 1.0053, Accuracy: 647/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 102	 Loss: 1.018357
#
#
# Test set: Average loss: 1.0374, Accuracy: 646/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 103	 Loss: 1.870256
#
#
# Test set: Average loss: 1.0955, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 104	 Loss: 0.770727
#
#
# Test set: Average loss: 1.0732, Accuracy: 647/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 105	 Loss: 1.967574
#
#
# Test set: Average loss: 1.1051, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 106	 Loss: 1.900107
#
#
# Test set: Average loss: 1.0774, Accuracy: 628/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 107	 Loss: 1.286977
#
#
# Test set: Average loss: 1.0308, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 108	 Loss: 1.242314
#
#
# Test set: Average loss: 1.0473, Accuracy: 635/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 109	 Loss: 1.117193
#
#
# Test set: Average loss: 1.0651, Accuracy: 632/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 110	 Loss: 1.437971
#
#
# Test set: Average loss: 1.0233, Accuracy: 646/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 111	 Loss: 1.131612
#
#
# Test set: Average loss: 1.0480, Accuracy: 629/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 112	 Loss: 1.486943
#
#
# Test set: Average loss: 1.0174, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 113	 Loss: 1.677155
#
#
# Test set: Average loss: 1.1055, Accuracy: 644/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 114	 Loss: 1.765442
#
#
# Test set: Average loss: 1.0725, Accuracy: 642/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 115	 Loss: 1.017658
#
#
# Test set: Average loss: 1.1013, Accuracy: 643/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 116	 Loss: 0.904279
#
#
# Test set: Average loss: 1.0968, Accuracy: 633/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 117	 Loss: 1.112116
#
#
# Test set: Average loss: 1.0350, Accuracy: 636/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 118	 Loss: 1.552447
#
#
# Test set: Average loss: 1.0298, Accuracy: 634/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 119	 Loss: 1.196490
#
#
# Test set: Average loss: 1.0967, Accuracy: 629/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 120	 Loss: 1.147746
#
#
# Test set: Average loss: 1.1531, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 121	 Loss: 1.721571
#
#
# Test set: Average loss: 1.0170, Accuracy: 636/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 122	 Loss: 1.243054
#
#
# Test set: Average loss: 1.0823, Accuracy: 648/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 123	 Loss: 1.674890
#
#
# Test set: Average loss: 1.0772, Accuracy: 632/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 124	 Loss: 1.514266
#
#
# Test set: Average loss: 1.0833, Accuracy: 633/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 125	 Loss: 0.705013
#
#
# Test set: Average loss: 1.1206, Accuracy: 640/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 126	 Loss: 1.930330
#
#
# Test set: Average loss: 1.0790, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 127	 Loss: 0.989680
#
#
# Test set: Average loss: 1.0805, Accuracy: 637/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 128	 Loss: 1.339646
#
#
# Test set: Average loss: 1.0298, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 129	 Loss: 1.550847
#
#
# Test set: Average loss: 1.0349, Accuracy: 633/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 130	 Loss: 1.305335
#
#
# Test set: Average loss: 1.0243, Accuracy: 638/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 131	 Loss: 1.567504
#
#
# Test set: Average loss: 1.0065, Accuracy: 641/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 132	 Loss: 2.270518
#
#
# Test set: Average loss: 1.0335, Accuracy: 642/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 133	 Loss: 1.433157
#
#
# Test set: Average loss: 1.1539, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 134	 Loss: 1.444113
#
#
# Test set: Average loss: 1.1174, Accuracy: 635/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 135	 Loss: 1.986717
#
#
# Test set: Average loss: 1.0733, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 136	 Loss: 0.549907
#
#
# Test set: Average loss: 1.0029, Accuracy: 640/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 137	 Loss: 0.996215
#
#
# Test set: Average loss: 1.1506, Accuracy: 625/1018 (61%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 138	 Loss: 0.872739
#
#
# Test set: Average loss: 1.0894, Accuracy: 625/1018 (61%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 139	 Loss: 1.446749
#
#
# Test set: Average loss: 1.1107, Accuracy: 630/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 140	 Loss: 0.945351
#
#
# Test set: Average loss: 1.0400, Accuracy: 649/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 141	 Loss: 1.070895
#
#
# Test set: Average loss: 1.0539, Accuracy: 654/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 142	 Loss: 1.248001
#
#
# Test set: Average loss: 1.1131, Accuracy: 625/1018 (61%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 143	 Loss: 0.415593
#
#
# Test set: Average loss: 1.0509, Accuracy: 648/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 144	 Loss: 1.384343
#
#
# Test set: Average loss: 1.1191, Accuracy: 632/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 145	 Loss: 0.575212
#
#
# Test set: Average loss: 1.0794, Accuracy: 640/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 146	 Loss: 0.569433
#
#
# Test set: Average loss: 1.0705, Accuracy: 653/1018 (64%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 147	 Loss: 0.912603
#
#
# Test set: Average loss: 1.1027, Accuracy: 642/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 148	 Loss: 0.740917
#
#
# Test set: Average loss: 1.0734, Accuracy: 629/1018 (62%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 149	 Loss: 1.199772
#
#
# Test set: Average loss: 1.0127, Accuracy: 641/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 150	 Loss: 1.450141
#
#
# Test set: Average loss: 1.0915, Accuracy: 643/1018 (63%)
#
# current best acc:  64.44007858546169
# -----------------------
# Train Epoch: 151	 Loss: 1.429916
#
#
# Test set: Average loss: 1.0035, Accuracy: 657/1018 (65%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 152	 Loss: 2.057530
#
#
# Test set: Average loss: 1.0102, Accuracy: 646/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 153	 Loss: 1.382092
#
#
# Test set: Average loss: 1.0365, Accuracy: 655/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 154	 Loss: 1.587382
#
#
# Test set: Average loss: 1.0627, Accuracy: 641/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 155	 Loss: 0.973169
#
#
# Test set: Average loss: 1.1070, Accuracy: 638/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 156	 Loss: 1.209475
#
#
# Test set: Average loss: 1.1320, Accuracy: 636/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 157	 Loss: 1.885571
#
#
# Test set: Average loss: 1.0478, Accuracy: 645/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 158	 Loss: 1.299527
#
#
# Test set: Average loss: 1.0471, Accuracy: 652/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 159	 Loss: 2.290686
#
#
# Test set: Average loss: 1.0351, Accuracy: 649/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 160	 Loss: 1.172421
#
#
# Test set: Average loss: 1.1117, Accuracy: 632/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 161	 Loss: 0.989505
# Test set: Average loss: 1.0165, Accuracy: 651/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 162	 Loss: 1.087935
#
#
# Test set: Average loss: 1.0176, Accuracy: 648/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 163	 Loss: 0.950329
#
#
# Test set: Average loss: 1.0244, Accuracy: 647/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 164	 Loss: 1.662253
#
#
# Test set: Average loss: 1.0770, Accuracy: 632/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 165	 Loss: 1.086835
#
#
# Test set: Average loss: 1.0395, Accuracy: 646/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 166	 Loss: 0.915393
#
#
# Test set: Average loss: 1.1064, Accuracy: 630/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 167	 Loss: 0.721974
#
#
# Test set: Average loss: 1.0744, Accuracy: 639/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 168	 Loss: 1.163797
#
#
# Test set: Average loss: 1.0889, Accuracy: 643/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 169	 Loss: 0.666309
#
#
# Test set: Average loss: 1.0703, Accuracy: 649/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 170	 Loss: 0.796161
#
#
# Test set: Average loss: 1.0663, Accuracy: 637/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 171	 Loss: 1.921179
#
#
# Test set: Average loss: 1.0404, Accuracy: 643/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 172	 Loss: 1.694628
#
#
# Test set: Average loss: 1.0456, Accuracy: 622/1018 (61%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 173	 Loss: 1.027241
#
#
# Test set: Average loss: 1.1636, Accuracy: 639/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 174	 Loss: 1.490081
#
#
# Test set: Average loss: 1.0100, Accuracy: 640/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 175	 Loss: 1.364537
#
#
# Test set: Average loss: 1.0454, Accuracy: 632/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 176	 Loss: 1.555128
#
#
# Test set: Average loss: 1.0302, Accuracy: 642/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 177	 Loss: 1.253093
#
#
# Test set: Average loss: 1.1087, Accuracy: 654/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 178	 Loss: 0.921031
#
#
# Test set: Average loss: 1.0729, Accuracy: 641/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 179	 Loss: 1.853931
#
#
# Test set: Average loss: 1.1410, Accuracy: 637/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 180	 Loss: 1.004013
#
#
# Test set: Average loss: 1.1143, Accuracy: 631/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 181	 Loss: 1.149127
#
#
# Test set: Average loss: 1.1198, Accuracy: 637/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 182	 Loss: 1.505957
#
#
# Test set: Average loss: 1.0449, Accuracy: 644/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 183	 Loss: 1.090194
#
#
# Test set: Average loss: 1.0901, Accuracy: 639/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 184	 Loss: 0.998173
#
#
# Test set: Average loss: 1.0720, Accuracy: 638/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 185	 Loss: 0.973234
#
#
# Test set: Average loss: 1.0987, Accuracy: 636/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 186	 Loss: 1.862839
#
#
# Test set: Average loss: 1.0336, Accuracy: 649/1018 (64%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 187	 Loss: 1.081766
#
#
# Test set: Average loss: 1.1124, Accuracy: 636/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 188	 Loss: 1.363423
#
#
# Test set: Average loss: 1.0637, Accuracy: 646/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 189	 Loss: 0.927341
#
#
# Test set: Average loss: 1.1052, Accuracy: 637/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 190	 Loss: 0.996506
#
#
# Test set: Average loss: 1.1283, Accuracy: 637/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 191	 Loss: 1.073037
#
#
# Test set: Average loss: 1.1907, Accuracy: 644/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 192	 Loss: 1.539195
#
#
# Test set: Average loss: 1.0522, Accuracy: 632/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 193	 Loss: 1.587322
#
#
# Test set: Average loss: 1.0689, Accuracy: 642/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 194	 Loss: 1.422046
#
#
# Test set: Average loss: 1.0742, Accuracy: 636/1018 (62%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 195	 Loss: 1.201041
#
#
# Test set: Average loss: 1.0473, Accuracy: 638/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 196	 Loss: 0.673706
#
#
# Test set: Average loss: 1.0903, Accuracy: 641/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 197	 Loss: 0.612562
#
#
# Test set: Average loss: 1.0975, Accuracy: 639/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 198	 Loss: 1.083712
#
#
# Test set: Average loss: 1.1321, Accuracy: 642/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Train Epoch: 199	 Loss: 1.281659
#
#
# Test set: Average loss: 1.1107, Accuracy: 638/1018 (63%)
#
# current best acc:  64.53831041257368
# -----------------------
# Result: at 151 epoch, achieved best acc: 65

# %%
# !nvidia-smi
